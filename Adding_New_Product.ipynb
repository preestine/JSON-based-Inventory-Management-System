# %%
import json

fd = open("Records.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'1001': {'Discount%': 0.5,
#   'Name': 'Dairy Milk',
#   'Price': 10,
#   'Purchase_Year': 2021,
#   'Quantity': 258},
#  '1002': {'Discount%': 6.7,
#   'Name': 'Cadbury Silk',
#   'Price': 60,
#   'Purchase_Year': 2021,
#   'Quantity': 81},
#  '1003': {'Discount%': 5.5,
#   'Name': '5 Star',
#   'Price': 25,
#   'Purchase_Year': 2021,
#   'Quantity': 19},
#  '1004': {'Discount%': 1.4,
#   'Name': 'Perk',
#   'Price': 5,
#   'Purchase_Year': 2021,
#   'Quantity': 66},
#  '1005': {'Discount%': 2.6,
#   'Name': 'Kit-Kat',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 91},
#  '1006': {'Discount%': 3.3,
#   'Name': 'Milky Bar',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 252},
#  '1007': {'Discount%': 7.9,
#   'Name': 'Bar-one',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 252},
#  '1008': {'Discount%': 9.9,
#   'Name': 'Munch',
#   'Price': 5,
#   'Purchase_Year': 2021,
#   'Quantity': 99},
#  '1009': {'Discount%': 9.0,
#   'Name': 'Ferrero Rocher',
#   'Price': 240,
#   'Purchase_Year': 2021,
#   'Quantity': 163},
#  '1010': {'Discount%': 8.8,
#   'Name': 'Galaxy',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 97},
#  '1011': {'Discount%': 7.1,
#   'Name': 'Snickers',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 282},
#  '1012': {'Discount%': 3.4,
#   'Name': 'Toblerone',
#   'Price': 200,
#   'Purchase_Year': 2021,
#   'Quantity': 217},
#  '1013': {'Discount%': 9.8,
#   'Name': "Hershey's Syrup",
#   'Price': 220,
#   'Purchase_Year': 2021,
#   'Quantity': 97},
#  '1014': {'Discount%': 7.1,
#   'Name': 'Amul Dark Chocolate',
#   'Price': 90,
#   'Purchase_Year': 2021,
#   'Quantity': 116},
#  '1015': {'Discount%': 3.7,
#   'Name': 'Lotte Choco Pie',
#   'Price': 15,
#   'Purchase_Year': 2021,
#   'Quantity': 54},
#  '1016': {'Discount%': 3.3,
#   'Name': 'Cadbury Fuse',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 295},
#  '1017': {'Discount%': 6.9,
#   'Name': "Hershey's Milk Chocolate",
#   'Price': 150,
#   'Purchase_Year': 2021,
#   'Quantity': 126},
#  '1018': {'Discount%': 5.6,
#   'Name': 'Bourbon Biscuit',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 79},
#  '1019': {'Discount%': 5.9,
#   'Name': 'Oreo Biscuit',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 166},
#  '1020': {'Discount%': 1.7,
#   'Name': 'Jim-Jam Biscuit',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 117},
#  '1021': {'Discount%': 3.3,
#   'Name': 'Hide & Seek',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 99},
#  '1022': {'Discount%': 3.7,
#   'Name': 'Dark Fantasy',
#   'Price': 50,
#   'Purchase_Year': 2021,
#   'Quantity': 77},
#  '1023': {'Discount%': 2.2,
#   'Name': 'Blue Lays',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 67},
#  '1024': {'Discount%': 9.2,
#   'Name': 'Green Lays',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 200},
#  '1025': {'Discount%': 9.5,
#   'Name': 'Uncle Chips',
#   'Price': 25,
#   'Purchase_Year': 2021,
#   'Quantity': 108},
#  '1026': {'Discount%': 8.7,
#   'Name': 'Kinder Joy',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 236},
#  '1027': {'Discount%': 7.8,
#   'Name': 'Fun Stix',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 108},
#  '1028': {'Discount%': 2.3,
#   'Name': 'Pringles',
#   'Price': 130,
#   'Purchase_Year': 2021,
#   'Quantity': 40},
#  '1029': {'Discount%': 8.9,
#   'Name': 'Kurkure',
#   'Price': 25,
#   'Purchase_Year': 2021,
#   'Quantity': 97},
#  '1030': {'Discount%': 4.9,
#   'Name': 'Mad Angles',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 54}}

# %%
for i in record:
  print(i,record[i]['Name'],record[i]['Quantity'])
# Out:
# 1001 Dairy Milk 258
# 1002 Cadbury Silk 81
# 1003 5 Star 19
# 1004 Perk 66
# 1005 Kit-Kat 91
# 1006 Milky Bar 252
# 1007 Bar-one 252
# 1008 Munch 99
# 1009 Ferrero Rocher 163
# 1010 Galaxy 97
# 1011 Snickers 282
# 1012 Toblerone 217
# 1013 Hershey's Syrup 97
# 1014 Amul Dark Chocolate 116
# 1015 Lotte Choco Pie 54
# 1016 Cadbury Fuse 295
# 1017 Hershey's Milk Chocolate 126
# 1018 Bourbon Biscuit 79
# 1019 Oreo Biscuit 166
# 1020 Jim-Jam Biscuit 117
# 1021 Hide & Seek 99
# 1022 Dark Fantasy 77
# 1023 Blue Lays 67
# 1024 Green Lays 200
# 1025 Uncle Chips 108
# 1026 Kinder Joy 236
# 1027 Fun Stix 108
# 1028 Pringles 40
# 1029 Kurkure 97
# 1030 Mad Angles 54

# %%
prod_id = str(input("Enter product id:"))
name = str(input("Enter Name:"))
pr = int(input("Enter Price:"))
qn = int(input("Enter Quantity:"))
py = str(input("Enter Purchase Year:"))


record[prod_id] = {'Name': name, 'Price': pr, 'Quantity': qn, 'Purchase_Year': py}

js = json.dumps(record)

fd = open("Records.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:1031
# Enter Name:twix
# Enter Price:55
# Enter Quantity:65
# Enter Purchase Year:23

# %%
record
# Out:
# {'1001': {'Discount%': 0.5,
#   'Name': 'Dairy Milk',
#   'Price': 10,
#   'Purchase_Year': 2021,
#   'Quantity': 258},
#  '1002': {'Discount%': 6.7,
#   'Name': 'Cadbury Silk',
#   'Price': 60,
#   'Purchase_Year': 2021,
#   'Quantity': 81},
#  '1003': {'Discount%': 5.5,
#   'Name': '5 Star',
#   'Price': 25,
#   'Purchase_Year': 2021,
#   'Quantity': 19},
#  '1004': {'Discount%': 1.4,
#   'Name': 'Perk',
#   'Price': 5,
#   'Purchase_Year': 2021,
#   'Quantity': 66},
#  '1005': {'Discount%': 2.6,
#   'Name': 'Kit-Kat',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 91},
#  '1006': {'Discount%': 3.3,
#   'Name': 'Milky Bar',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 252},
#  '1007': {'Discount%': 7.9,
#   'Name': 'Bar-one',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 252},
#  '1008': {'Discount%': 9.9,
#   'Name': 'Munch',
#   'Price': 5,
#   'Purchase_Year': 2021,
#   'Quantity': 99},
#  '1009': {'Discount%': 9.0,
#   'Name': 'Ferrero Rocher',
#   'Price': 240,
#   'Purchase_Year': 2021,
#   'Quantity': 163},
#  '1010': {'Discount%': 8.8,
#   'Name': 'Galaxy',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 97},
#  '1011': {'Discount%': 7.1,
#   'Name': 'Snickers',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 282},
#  '1012': {'Discount%': 3.4,
#   'Name': 'Toblerone',
#   'Price': 200,
#   'Purchase_Year': 2021,
#   'Quantity': 217},
#  '1013': {'Discount%': 9.8,
#   'Name': "Hershey's Syrup",
#   'Price': 220,
#   'Purchase_Year': 2021,
#   'Quantity': 97},
#  '1014': {'Discount%': 7.1,
#   'Name': 'Amul Dark Chocolate',
#   'Price': 90,
#   'Purchase_Year': 2021,
#   'Quantity': 116},
#  '1015': {'Discount%': 3.7,
#   'Name': 'Lotte Choco Pie',
#   'Price': 15,
#   'Purchase_Year': 2021,
#   'Quantity': 54},
#  '1016': {'Discount%': 3.3,
#   'Name': 'Cadbury Fuse',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 295},
#  '1017': {'Discount%': 6.9,
#   'Name': "Hershey's Milk Chocolate",
#   'Price': 150,
#   'Purchase_Year': 2021,
#   'Quantity': 126},
#  '1018': {'Discount%': 5.6,
#   'Name': 'Bourbon Biscuit',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 79},
#  '1019': {'Discount%': 5.9,
#   'Name': 'Oreo Biscuit',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 166},
#  '1020': {'Discount%': 1.7,
#   'Name': 'Jim-Jam Biscuit',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 117},
#  '1021': {'Discount%': 3.3,
#   'Name': 'Hide & Seek',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 99},
#  '1022': {'Discount%': 3.7,
#   'Name': 'Dark Fantasy',
#   'Price': 50,
#   'Purchase_Year': 2021,
#   'Quantity': 77},
#  '1023': {'Discount%': 2.2,
#   'Name': 'Blue Lays',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 67},
#  '1024': {'Discount%': 9.2,
#   'Name': 'Green Lays',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 200},
#  '1025': {'Discount%': 9.5,
#   'Name': 'Uncle Chips',
#   'Price': 25,
#   'Purchase_Year': 2021,
#   'Quantity': 108},
#  '1026': {'Discount%': 8.7,
#   'Name': 'Kinder Joy',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 236},
#  '1027': {'Discount%': 7.8,
#   'Name': 'Fun Stix',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 108},
#  '1028': {'Discount%': 2.3,
#   'Name': 'Pringles',
#   'Price': 130,
#   'Purchase_Year': 2021,
#   'Quantity': 40},
#  '1029': {'Discount%': 8.9,
#   'Name': 'Kurkure',
#   'Price': 25,
#   'Purchase_Year': 2021,
#   'Quantity': 97},
#  '1030': {'Discount%': 4.9,
#   'Name': 'Mad Angles',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 54},
#  '1031': {'Name': 'Twix', 'Price': 55, 'Purchase_Year': '23', 'Quantity': 65}}

# %%
del record['1031']

# %%
record
# Out:
# {'1001': {'Discount%': 0.5,
#   'Name': 'Dairy Milk',
#   'Price': 10,
#   'Purchase_Year': 2021,
#   'Quantity': 258},
#  '1002': {'Discount%': 6.7,
#   'Name': 'Cadbury Silk',
#   'Price': 60,
#   'Purchase_Year': 2021,
#   'Quantity': 81},
#  '1003': {'Discount%': 5.5,
#   'Name': '5 Star',
#   'Price': 25,
#   'Purchase_Year': 2021,
#   'Quantity': 19},
#  '1004': {'Discount%': 1.4,
#   'Name': 'Perk',
#   'Price': 5,
#   'Purchase_Year': 2021,
#   'Quantity': 66},
#  '1005': {'Discount%': 2.6,
#   'Name': 'Kit-Kat',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 91},
#  '1006': {'Discount%': 3.3,
#   'Name': 'Milky Bar',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 252},
#  '1007': {'Discount%': 7.9,
#   'Name': 'Bar-one',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 252},
#  '1008': {'Discount%': 9.9,
#   'Name': 'Munch',
#   'Price': 5,
#   'Purchase_Year': 2021,
#   'Quantity': 99},
#  '1009': {'Discount%': 9.0,
#   'Name': 'Ferrero Rocher',
#   'Price': 240,
#   'Purchase_Year': 2021,
#   'Quantity': 163},
#  '1010': {'Discount%': 8.8,
#   'Name': 'Galaxy',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 97},
#  '1011': {'Discount%': 7.1,
#   'Name': 'Snickers',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 282},
#  '1012': {'Discount%': 3.4,
#   'Name': 'Toblerone',
#   'Price': 200,
#   'Purchase_Year': 2021,
#   'Quantity': 217},
#  '1013': {'Discount%': 9.8,
#   'Name': "Hershey's Syrup",
#   'Price': 220,
#   'Purchase_Year': 2021,
#   'Quantity': 97},
#  '1014': {'Discount%': 7.1,
#   'Name': 'Amul Dark Chocolate',
#   'Price': 90,
#   'Purchase_Year': 2021,
#   'Quantity': 116},
#  '1015': {'Discount%': 3.7,
#   'Name': 'Lotte Choco Pie',
#   'Price': 15,
#   'Purchase_Year': 2021,
#   'Quantity': 54},
#  '1016': {'Discount%': 3.3,
#   'Name': 'Cadbury Fuse',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 295},
#  '1017': {'Discount%': 6.9,
#   'Name': "Hershey's Milk Chocolate",
#   'Price': 150,
#   'Purchase_Year': 2021,
#   'Quantity': 126},
#  '1018': {'Discount%': 5.6,
#   'Name': 'Bourbon Biscuit',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 79},
#  '1019': {'Discount%': 5.9,
#   'Name': 'Oreo Biscuit',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 166},
#  '1020': {'Discount%': 1.7,
#   'Name': 'Jim-Jam Biscuit',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 117},
#  '1021': {'Discount%': 3.3,
#   'Name': 'Hide & Seek',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 99},
#  '1022': {'Discount%': 3.7,
#   'Name': 'Dark Fantasy',
#   'Price': 50,
#   'Purchase_Year': 2021,
#   'Quantity': 77},
#  '1023': {'Discount%': 2.2,
#   'Name': 'Blue Lays',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 67},
#  '1024': {'Discount%': 9.2,
#   'Name': 'Green Lays',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 200},
#  '1025': {'Discount%': 9.5,
#   'Name': 'Uncle Chips',
#   'Price': 25,
#   'Purchase_Year': 2021,
#   'Quantity': 108},
#  '1026': {'Discount%': 8.7,
#   'Name': 'Kinder Joy',
#   'Price': 40,
#   'Purchase_Year': 2021,
#   'Quantity': 236},
#  '1027': {'Discount%': 7.8,
#   'Name': 'Fun Stix',
#   'Price': 20,
#   'Purchase_Year': 2021,
#   'Quantity': 108},
#  '1028': {'Discount%': 2.3,
#   'Name': 'Pringles',
#   'Price': 130,
#   'Purchase_Year': 2021,
#   'Quantity': 40},
#  '1029': {'Discount%': 8.9,
#   'Name': 'Kurkure',
#   'Price': 25,
#   'Purchase_Year': 2021,
#   'Quantity': 97},
#  '1030': {'Discount%': 4.9,
#   'Name': 'Mad Angles',
#   'Price': 30,
#   'Purchase_Year': 2021,
#   'Quantity': 54}}
